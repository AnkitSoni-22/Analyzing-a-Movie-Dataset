# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
#   Cell In[1], line 4
#     import seaborn as sns
#           ^
# SyntaxError: invalid non-printable character U+00A0

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
movies_df = pd.read_csv("movies.csv")

# %%
movies_df.head()
# Out:
#        id                             title                            genres  \
# 0  615656                 Meg 2: The Trench     Action-Science Fiction-Horror
# 1  758323               The Pope's Exorcist           Horror-Mystery-Thriller
# 2  533535              Deadpool & Wolverine     Action-Comedy-Science Fiction
# 3  667538  Transformers: Rise of the Beasts  Action-Adventure-Science Fiction
# 4  693134                    Dune: Part Two         Science Fiction-Adventure
#
#   original_language                                           overview  \
# 0                en  An exploratory dive into the deepest depths of...
# 1                en  Father Gabriele Amorth Chief Exorcist of the V...
# 2                en  A listless Wade Wilson toils away in civilian ...
# 3                en  When a new threat capable of destroying the en...
# 4                en  Follow the mythic journey of Paul Atreides as ...
#
# ...

# %%
movies_df.shape
# Out:
# (722332, 20)

# %% [markdown]
# movies_df.info()

# %%
movies_df.isnull().sum()
# Out:
# id                           0
# title                        6
# genres                  210331
# original_language            0
# overview                118247
# popularity                   0
# production_companies    384951
# release_date             51565
# budget                       0
# revenue                      0
# runtime                  34338
# status                       0
# tagline                 613867
# vote_average                 0
# vote_count                   0
# credits                 224726
# keywords                511705
# poster_path             184513
# backdrop_path           499131
# recommendations         686394
# dtype: int64

# %%
movies_df.drop('recommendations', axis=1, inplace=True)

# %%
movies_df.shape
# Out:
# (722332, 19)

# %%
movies_df.dropna(inplace=True)

# %%
movies_df.shape
# Out:
# (40243, 19)

# %%
movies_df.isnull().sum()
# Out:
# id                      0
# title                   0
# genres                  0
# original_language       0
# overview                0
# popularity              0
# production_companies    0
# release_date            0
# budget                  0
# revenue                 0
# runtime                 0
# status                  0
# tagline                 0
# vote_average            0
# vote_count              0
# credits                 0
# keywords                0
# poster_path             0
# backdrop_path           0
# dtype: int64

# %%
movies_df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 721244    False
# 721686    False
# 722115    False
# 722123    False
# 722143    False
# Length: 40243, dtype: bool

# %%
movies_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies_df.drop_duplicates(inplace=True)

# %%
movies_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies_df.dtype
# Out:
# id                        int64
# title                    object
# genres                   object
# original_language        object
# overview                 object
# popularity              float64
# production_companies     object
# release_date             object
# budget                  float64
# revenue                 float64
# runtime                 float64
# status                   object
# tagline                  object
# vote_average            float64
# vote_count              float64
# credits                  object
# keywords                 object
# poster_path              object
# backdrop_path            object
# dtype: object

# %%
movies_df['release_date']= movies_df['release_date'].astype(object)

# %%
all_genres = movies_df['genres'].dropna().str.split('-').sum()

# %%
genres_df = pd.DataFrame(all_genres, columns=['genres'])

# %%
genre_counts = genres_df['genres'].value_counts()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=genre_counts.index, y=genre_counts.values, color="Red")
plt.title('Distribution of Movies Genres')
plt.xlabel('Genre')
plt.ylabel('Number og Movies')
plt.xticks(rotation=45)
plt.show()

# %%
movies_df['revenue'] = pd.to_numeric(movies_df['revenue'],errors='coerce')

# %%
top_10_highest_grossing=movies_df.sort_values(by='revenue',ascending=False).head(10)

# %%
print(top_10_highest_grossing[['title','revenue']])
# Out:
#                              title       revenue
# 151                         Avatar  2.920357e+09
# 247              Avengers: Endgame  2.799439e+09
# 147       Avatar: The Way of Water  2.320250e+09
# 314                        Titanic  2.187464e+09
# 1077  Star Wars: The Force Awakens  2.068224e+09
# 268         Avengers: Infinity War  2.052415e+09
# 227        Spider-Man: No Way Home  1.921847e+09
# 580                 Jurassic World  1.671537e+09
# 425                  The Lion King  1.663075e+09
# 607                   The Avengers  1.518816e+09

# %%
movies_df['budget'] = pd.to_numeric(movies_df['budget'],errors='coerce')

# %%
correlation = movies_df['budget'].corr(movies_df['revenue'])

# %% [raw]
# print(f"Correlation between budget and revenue: {correlation}")

# %%
print(f"Correlation between budget and revenue: {correlation}")
# Out:
# Correlation between budget and revenue: 0.7668473482060916

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=movies_df, x='budget', y='revenue', alpha=0.5)
plt.title('Relationship Between Movie Budget and Revenue')
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.show()

# %%
movies_df['release_date'] = pd.to_datetime(movies_df['release_date'],errors='coerce')

# %%
movies_df['release_year'] = movies_df['release_date'].dt.year

# %%
movies_per_year = movies_df['release_year'].value_counts().sort_index()

# %%
plt.figure(figsize=(12, 6))
plt.plot(movies_per_year.index, movies_per_year.values, marker='o', linestyle='-', color='pink')
plt.title('Trend of Movie Production Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Movies Produced')
plt.grid(True)
plt.show()
